# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('income.csv',names=['Name','income'],skiprows=[0])

# %%
df
# Out:
#         Name    income
# 0        Rob      5000
# 1      Rafiq      6000
# 2       Nina      4000
# 3      Sofia      7500
# 4      Mohan      8000
# 5        Tao      7000
# 6  Elon Musk  10000000

# %%
df['income'][3]=np.NaN

# %%
df
# Out:
#         Name      income
# 0        Rob      5000.0
# 1      Rafiq      6000.0
# 2       Nina      4000.0
# 3      Sofia         NaN
# 4      Mohan      8000.0
# 5        Tao      7000.0
# 6  Elon Musk  10000000.0

# %%
df.income.mean()
# Out:
# 1671666.6666666667

# %%
df_new=df.fillna(df.income.mean())

# %%
df_new
# Out:
#         Name        income
# 0        Rob  5.000000e+03
# 1      Rafiq  6.000000e+03
# 2       Nina  4.000000e+03
# 3      Sofia  1.671667e+06
# 4      Mohan  8.000000e+03
# 5        Tao  7.000000e+03
# 6  Elon Musk  1.000000e+07

# %%
df.income.median()
# Out:
# 6500.0

# %%
df_new2=df.fillna(df.income.median())

# %%
df_new2
# Out:
#         Name      income
# 0        Rob      5000.0
# 1      Rafiq      6000.0
# 2       Nina      4000.0
# 3      Sofia      6500.0
# 4      Mohan      8000.0
# 5        Tao      7000.0
# 6  Elon Musk  10000000.0

# %% [markdown]
# # As the mean value is more as compared to median so the replacement with mean  got incorrect result so it is shows that there is an outlier so insted of meaan we use median

# %%
#nominal,categorical,quantitative,qualitative----->mode

# %%
df=pd.read_csv('modified ethnic.csv')

# %%
df
# Out:
#                      Position State Sex MaritalDesc CitizenDesc  \
# 0                Accountant I   NaN   F     Married  US Citizen
# 1                Accountant I    MA  M     Divorced  US Citizen
# 2                Accountant I    MA  M       Single         NaN
# 3    Administrative Assistant    MA   F         NaN  US Citizen
# 4                         NaN    MA   F      Single  US Citizen
# ..                        ...   ...  ..         ...         ...
# 305      Sr. Network Engineer    CT   F     Married  US Citizen
# 306      Sr. Network Engineer    MA  M      Married  US Citizen
# 307                       NaN    MA  M      Married  US Citizen
# 308      Sr. Network Engineer    CT  M          NaN  US Citizen
# 309      Sr. Network Engineer    MA   F     Widowed  US Citizen
#
#          EmploymentStatus     Department  Salaries   age  \
# 0                  Active  Admin Offices    674.28   NaN
# 1                  Active  Admin Offices    674.28  50.0
# ...

# %%
#Check Null values

df.isnull().sum()
# Out:
# Position            43
# State               35
# Sex                 34
# MaritalDesc         29
# CitizenDesc         27
# EmploymentStatus    32
# Department          18
# Salaries            32
# age                 35
# Race                25
# dtype: int64

# %%
df.isna().sum()
# Out:
# Position            43
# State               35
# Sex                 34
# MaritalDesc         29
# CitizenDesc         27
# EmploymentStatus    32
# Department          18
# Salaries            32
# age                 35
# Race                25
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
#Create an imputer that create an nan value
#

# %%
mean_imputer=SimpleImputer(missing_values=np.nan,strategy='mean')

# %%
df['Salaries']=pd.DataFrame(mean_imputer.fit_transform(df[['Salaries']]))
#It will replace the all the nan values are replaced with mean value

# %%
df.Salaries.isna().sum()
# Out:
# 0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('ethnic diversity.csv')
df.shape
# Out:
# (310, 13)

# %%
df_new=pd.get_dummies(df)

# %%
df_new
# Out:
#           EmpID   Zip  Salaries  age  Employee_Name_Adinolfi, Wilson  K  \
# 0    1103024456  1450    674.28   28                                  0
# 1    1106026572  1460    674.28   50                                  0
# 2    1302053333  2703    674.28   43                                  0
# 3    1211050782  2170  47822.00   44                                  0
# 4    1307059817  2330  61089.35   33                                  0
# ..          ...   ...       ...  ...                                ...
# 305  1411071312  6033  37619.01   38                                  0
# 306  1108028108  2169  27603.00   34                                  0
# 307   904013591  1545  27587.46   24                                  0
# 308  1308060959  6278  12126.53   31                                  0
# 309  1301052347  2453  37257.00   46                                  0
#
#      Employee_Name_Ait Sidi, Karthikeyan     Employee_Name_Akinkuolie, Sarah  \
# ...
