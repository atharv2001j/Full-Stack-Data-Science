# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('cars.csv')

# %%
df
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
df.shape
# Out:
# (81, 5)

# %%
df.columns
# Out:
# Index(['HP', 'MPG', 'VOL', 'SP', 'WT'], dtype='object')

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]>

# %%
df.dtypes
# Out:
# HP       int64
# MPG    float64
# VOL      int64
# SP     float64
# WT     float64
# dtype: object

# %%
plt.scatter(df['HP'],df['MPG'])
plt.xlabel('HP')
plt.ylabel('MPG')
plt.show()

# most of the bike are of the range 50-100

# %%
sns.pairplot(df)

# %%
#Boxplot for outliers
sns.boxplot(df['HP'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df['WT'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df['SP'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df['VOL'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df['MPG'])
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df['HP'],kde=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_7436\2705035857.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['HP'],kde=True)
# <AxesSubplot:xlabel='HP', ylabel='Density'>

# %%
sns.distplot(df['SP'],kde=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_7436\748871817.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SP'],kde=True)
# <AxesSubplot:xlabel='SP', ylabel='Density'>

# %%
sns.distplot(df['MPG'],kde=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_7436\503178122.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['MPG'],kde=True)
# <AxesSubplot:xlabel='MPG', ylabel='Density'>

# %%
# plot pdf and cdf
counts,bin_edges = np.histogram(df['HP'], bins=10, density = True)
pdf = counts/(sum(counts))
print(pdf)
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)


counts, bin_edges = np.histogram(df['HP'], bins=20, 
                                 density = True)
pdf = counts/(sum(counts))
plt.plot(bin_edges[1:],pdf)
plt.grid()
plt.show()

# It is observed that the speed is vary in the range of 7.5 to 25.
# Out:
# [0.18518519 0.43209877 0.11111111 0.07407407 0.11111111 0.
#  0.02469136 0.02469136 0.01234568 0.02469136]
# [ 49.   76.3 103.6 130.9 158.2 185.5 212.8 240.1 267.4 294.7 322. ]

# %%
# plot pdf and cdf
counts,bin_edges = np.histogram(df['MPG'], bins=10, density = True)
pdf = counts/(sum(counts))
print(pdf)
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)


counts, bin_edges = np.histogram(df['MPG'], bins=20, 
                                 density = True)
pdf = counts/(sum(counts))
plt.plot(bin_edges[1:],pdf)
plt.grid()
plt.show()

# It is observed that the speed is vary in the range of 7.5 to 25.
# Out:
# [0.01234568 0.07407407 0.12345679 0.04938272 0.12345679 0.18518519
#  0.20987654 0.09876543 0.0617284  0.0617284 ]
# [12.10126289 16.26120474 20.42114659 24.58108844 28.74103029 32.90097213
#  37.06091398 41.22085583 45.38079768 49.54073953 53.70068138]

# %%
df.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
df.mean()
# Out:
# HP     117.469136
# MPG     34.422076
# VOL     98.765432
# SP     121.540272
# WT      32.412577
# dtype: float64

# %%
#Skewness

from scipy.stats import skew
from scipy.stats import kurtosis

# %%
sp_lst=df['HP'].tolist()
print(skew(sp_lst))
print(kurtosis(sp_lst,axis=0,bias=True))

#The skewness of the speed is positive to there is right skkew and data is distributed
# Out:
# 1.684269690374973
# 2.7072670776142544

# %%
sp_lst=df['MPG'].tolist()
print(skew(sp_lst))
print(kurtosis(sp_lst,axis=0,bias=True))

#The skewness of the speed is negative to there is left skkew and data is distributed
# Out:
# -0.17463433818755686
# -0.6477383960245926

# %%
#calculate the median for outlier
print("\nMedians:")
print(np.median(df["HP"]))
#Median with an outlier
print(np.median(np.append(df["HP"],50)));
# Out:
# Medians:
# 100.0
# 99.0
